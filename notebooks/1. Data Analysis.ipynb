# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os
from tqdm.notebook import tqdm

from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
from pandas.io.parsers import ParserError

# %%
cd ..
# Out:
# /home/suriya/dcu/Group-Project

# %%
trainset_key = pd.read_csv('data/tc4tl_training_data_v1/tc4tl/docs/tc4tl_train_key.tsv', sep='\t')
trainset_key
# Out:
#                      fileid phone_carriage_state  distance_in_meters  \
# 0      aaadbuvp_tc4tl20.csv          pocket_hand                 1.8
# 1      aaamkcii_tc4tl20.csv        pocket_pocket                 3.0
# 2      aabqtowt_tc4tl20.csv            hand_hand                 1.2
# 3      aadkjwss_tc4tl20.csv        pocket_pocket                 1.8
# 4      aafzrgzt_tc4tl20.csv            hand_hand                 1.8
# ...                     ...                  ...                 ...
# 15547  zzwcoemu_tc4tl20.csv          pocket_hand                 1.2
# 15548  zzwoqxuc_tc4tl20.csv            hand_hand                 4.5
# 15549  zzymwbbb_tc4tl20.csv        pocket_pocket                 1.2
# 15550  zzzflikz_tc4tl20.csv            hand_hand                 1.8
# 15551  zzzjbxhg_tc4tl20.csv            hand_hand                 1.2
#
#        step_size_in_sec coarse_grain
# 0                    50            Y
# 1                    80            N
# 2                    60            N
# 3                    20            N
# 4                    60            Y
# ...                 ...          ...
# 15547                80            N
# 15548                70            N
# 15549                10            N
# 15550               100            Y
# 15551               120            N
#
# [15552 rows x 5 columns]

# %%
trainset_dir = 'data/tc4tl_training_data_v1/tc4tl/data/train/'

# %%
data = []
for filename in tqdm(os.listdir(trainset_dir)):
    try:
        data.append(pd.read_csv(os.path.join(trainset_dir, filename)))
    except ParserError:
        print("parse error in", filename)

# %%
content = open(os.path.join(trainset_dir, "qcsvvfhe_tc4tl20.csv")).read()

# %%
bluetooth = [ line.split(',') for line in content.split('\n') if 'Bluetooth' in line ]
pd.DataFrame(bluetooth, columns=['Time', 'Sensor', 'Rssi'])
# Out:
#         Time     Sensor Rssi
# 0      0.000  Bluetooth  -53
# 1      0.002  Bluetooth  -54
# 2      0.030  Bluetooth  -52
# 3      0.060  Bluetooth  -81
# 4      0.063  Bluetooth  -81
# ..       ...        ...  ...
# 583  274.456  Bluetooth  -69
# 584  274.483  Bluetooth  -64
# 585  274.486  Bluetooth  -65
# 586  274.513  Bluetooth  -63
# 587  274.516  Bluetooth  -63
#
# [588 rows x 3 columns]

# %%
gyro = [ line.split(',') for line in content.split('\n') if 'Gyroscope' in line ]
pd.DataFrame(gyro, columns=['Time', 'Sensor', 'X', 'Y', 'Z'])
# Out:
#        Time     Sensor                        X                      Y  \
# 0     0.129  Gyroscope     -0.05759645253419876  -0.046543534845113754
# 1     0.377  Gyroscope      0.02358095906674862  -0.015076953917741776
# 2     0.629  Gyroscope    -0.005277586169540882   0.020351877436041832
# 3     0.879  Gyroscope  -0.00020985709852539003  -0.006172941066324711
# 4     1.129  Gyroscope      0.03334756940603256   0.010627077892422676
# ..      ...        ...                      ...                    ...
# 59  273.442  Gyroscope     0.014213557355105877    0.00808908510953188
# 60  273.692  Gyroscope     0.007144462317228317  -0.005586512852460146
# 61  273.943  Gyroscope      0.01483513880521059    0.03887362778186798
# 62  274.192  Gyroscope     0.018366223201155663   0.014153636060655117
# 63  274.444  Gyroscope     0.010068346746265888   0.015614645555615425
#
#                          Z
# 0     0.016338760033249855
# 1   -0.0005605954211205244
# 2     0.037083983421325684
# 3      0.07685749977827072
# 4    -0.046491868793964386
# ..                     ...
# 59  -0.0032839439809322357
# 60     0.01417627278715372
# 61    -0.00845819991081953
# 62    0.012083294801414013
# 63     0.03967124596238136
#
# [64 rows x 5 columns]

# %%
acc = [ line.split(',') for line in content.split('\n') if 'Accelerometer' in line ]
pd.DataFrame(acc, columns=['Time', 'Sensor', 'X', 'Y', 'Z'])
# Out:
#        Time         Sensor                   X                    Y  \
# 0     0.127  Accelerometer  0.0335235595703125  -0.1985015869140625
# 1     0.375  Accelerometer   0.017059326171875  -0.1985931396484375
# 2     0.626  Accelerometer   0.038665771484375    -0.21441650390625
# 3     0.876  Accelerometer    0.01788330078125   -0.218536376953125
# 4     1.126  Accelerometer  0.0208892822265625   -0.223175048828125
# ..      ...            ...                 ...                  ...
# 59  273.440  Accelerometer  0.0133819580078125    -0.25091552734375
# 60  273.690  Accelerometer  0.0049896240234375  -0.2440643310546875
# 61  273.941  Accelerometer   0.011810302734375  -0.2558441162109375
# 62  274.190  Accelerometer       0.01904296875  -0.2578582763671875
# 63  274.441  Accelerometer  0.0101165771484375  -0.2455291748046875
#
#                       Z
# 0   -0.9685821533203125
# 1   -0.9871368408203125
# 2   -0.9739532470703125
# 3    -0.977447509765625
# 4    -0.959259033203125
# ..                  ...
# 59         -0.978515625
# 60   -0.958160400390625
# 61  -0.9538116455078125
# 62  -0.9544525146484375
# 63   -0.942657470703125
#
# [64 rows x 5 columns]

# %%
alt = [ line.split(',') for line in content.split('\n') if 'Altitude' in line ]
pd.DataFrame(alt, columns=['Time', 'Sensor', 'X', 'Y'])
# Out:
#        Time    Sensor                     X                   Y
# 0     0.770  Altitude     -0.31707763671875  100.25433349609375
# 1     1.754  Altitude      -0.3355712890625  100.25454711914062
# 2     2.702  Altitude     -0.36199951171875  100.25487518310547
# 3     3.649  Altitude   -0.3831329345703125  100.25511169433594
# 4    91.030  Altitude          -0.044921875  100.25547790527344
# 5    92.054  Altitude  -0.07134246826171875  100.25579071044922
# 6    93.077  Altitude  -0.10305023193359375  100.25616455078125
# 7    94.101  Altitude  -0.11890411376953125  100.25634002685547
# 8   179.007  Altitude  -0.01056671142578125   100.2530288696289
# 9   179.991  Altitude  -0.01056671142578125   100.2530288696289
# 10  180.938  Altitude  -0.01056671142578125   100.2530288696289
# 11  181.886  Altitude  -0.01056671142578125   100.2530288696289
# 12  271.577  Altitude    0.0792694091796875  100.25143432617188
# 13  272.601  Altitude   0.09247589111328125  100.25128936767578
# 14  273.586  Altitude    0.0977630615234375    100.251220703125
# 15  274.532  Altitude   0.10832977294921875   100.2510986328125

# %%
att = [ line.split(',') for line in content.split('\n') if 'Attitude' in line ]
pd.DataFrame(att, columns=['Time', 'Sensor', 'X', 'Y', 'Z'])
# Out:
#        Time    Sensor                    X                     Y  \
# 0     0.131  Attitude  0.20342969676284012  0.026804854704584356
# 1     0.379  Attitude  0.21104424268433314  0.025844757192604595
# 2     0.631  Attitude  0.21806288414172612   0.02865782656909153
# 3     0.881  Attitude   0.2225938692574916  0.025318692670374565
# 4     1.132  Attitude  0.21916654020633652  0.024449933251685756
# ..      ...       ...                  ...                   ...
# 59  273.444  Attitude   0.2533726086810827  0.009613154199302866
# 60  273.694  Attitude  0.25183927087129254  0.010654720605795082
# 61  273.946  Attitude  0.25173284256471434  0.010376123573449775
# 62  274.194  Attitude   0.2547560107308552  0.011532670925109161
# 63  274.447  Attitude   0.2528645318585439  0.014460060733765627
#
#                        Z
# 0     -2.154223097176316
# 1     -2.158459566894034
# 2    -2.1512630777992268
# 3    -2.1327767936842164
# 4     -2.140776451704658
# ..                   ...
# 59   -0.2358639942984172
# 60  -0.23551633267703231
# 61   -0.2336902834581501
# 62  -0.22958175153953578
# 63  -0.22095103540816863
#
# [64 rows x 5 columns]

# %%
mag = [ line.split(',') for line in content.split('\n') if 'Magnetic-field' in line ]
pd.DataFrame(mag, columns=['Time', 'Sensor', 'X', 'Y', 'Z', 'Accuracy'])
# Out:
#        Time          Sensor                    X                    Y  \
# 0     0.133  Magnetic-field  -11.175308227539062      9.5548095703125
# 1     0.381  Magnetic-field  -11.287628173828125    9.249008178710938
# 2     0.634  Magnetic-field  -11.292823791503906    8.847763061523438
# 3     0.883  Magnetic-field  -10.891120910644531    8.588958740234375
# 4     1.134  Magnetic-field  -10.957138061523438    9.087448120117188
# ..      ...             ...                  ...                  ...
# 59  273.446  Magnetic-field    13.13763427734375  -4.2371368408203125
# 60  273.696  Magnetic-field    13.35614013671875  -4.4061737060546875
# 61  273.948  Magnetic-field   13.272308349609375  -4.1440582275390625
# 62  274.196  Magnetic-field   13.110427856445312  -4.5719146728515625
# 63  274.448  Magnetic-field   13.569732666015625     -4.6607666015625
#
#                       Z Accuracy
# 0   -45.033660888671875     high
# 1   -45.160736083984375     high
# 2   -44.986297607421875     high
# 3    -45.18299865722656     high
# 4    -45.08100891113281     high
# ..                  ...      ...
# 59   -42.50923156738281     high
# 60  -42.395233154296875     high
# 61   -42.86883544921875     high
# 62   -42.66502380371094     high
# 63   -42.70733642578125     high
#
# [64 rows x 6 columns]

# %% [markdown]
# ## Abstraction

# %%
from src.datapoint import DataPoint

# %%
datapoint = DataPoint('data/tc4tl_training_data_v1/tc4tl/data/train/aaadbuvp_tc4tl20.csv')

# %% [markdown]
# Bluetooth at
# $$t=0 s$$

# %%
datapoint.at(t=0., sensors=['Bluetooth'], reset_index=True)
# Out:
#    Time     Sensor  Rssi
# 0   0.0  Bluetooth -77.0

# %% [markdown]
# Magnetic-field less than
# $$t < 400s$$

# %%
datapoint.before(t=400., sensors=['Magnetic-field'], reset_index=True)
# Out:
#         Time          Sensor          X          Y          Z Accuracy
# 0      0.065  Magnetic-field -10.326216 -46.677151 -31.518311     high
# 1      0.313  Magnetic-field  -9.793383 -44.927494 -33.463257     high
# 2      0.564  Magnetic-field  -9.703075 -45.006191 -33.289062     high
# 3      0.814  Magnetic-field  -9.668869 -45.351646 -33.108093     high
# 4      1.065  Magnetic-field  -9.784548 -45.291050 -33.121490     high
# ..       ...             ...        ...        ...        ...      ...
# 122  395.705  Magnetic-field  -8.815342 -57.980980  -0.561279     high
# 123  395.954  Magnetic-field  -8.551502 -58.257423  -0.628357     high
# 124  396.205  Magnetic-field  -8.638908 -58.154209  -0.333984     high
# 125  396.454  Magnetic-field  -8.814350 -58.326351  -0.383453     high
# 126  396.707  Magnetic-field  -8.300751 -58.441452  -0.031128     high
#
# [127 rows x 6 columns]

# %% [markdown]
# Gyroscope greater than $$t > 90s$$

# %%
datapoint.after(t=90., sensors=['Gyroscope'], reset_index=True)
# Out:
#         Time     Sensor         X         Y         Z
# 0    106.806  Gyroscope  0.030339  0.034013 -0.031148
# 1    107.056  Gyroscope -0.014547  0.011699 -0.007465
# 2    107.306  Gyroscope  0.021154  0.003328  0.014571
# 3    107.559  Gyroscope -0.008869 -0.026030  0.004281
# 4    107.808  Gyroscope -0.034537 -0.014865  0.012671
# ..       ...        ...       ...       ...       ...
# 138  566.929  Gyroscope -0.009319  0.011437  0.011974
# 139  567.181  Gyroscope -0.032997  0.056083  0.004740
# 140  567.431  Gyroscope  0.032053 -0.007967  0.006909
# 141  567.681  Gyroscope -0.088183  0.063605 -0.034478
# 142  567.931  Gyroscope  0.019021  0.012848 -0.013756
#
# [143 rows x 5 columns]

# %% [markdown]
# Altitude between
# $$20s < t < 300s$$

# %%
datapoint.bw(t1=90., t2=300., sensors=['Altitude'], reset_index=True)
# Out:
#        Time    Sensor         X          Y
# 0   107.345  Altitude  0.000000  99.984146
# 1   108.372  Altitude  0.007927  99.984039
# 2   109.399  Altitude  0.018494  99.983932
# 3   110.426  Altitude  0.034348  99.983742
# 4   160.487  Altitude -0.454483  99.976196
# 5   161.514  Altitude -0.687004  99.978958
# 6   162.542  Altitude -0.811195  99.980415
# 7   163.570  Altitude -0.864037  99.981056
# 8   215.624  Altitude  0.013214  99.984375
# 9   216.651  Altitude  0.029068  99.984207
# 10  217.678  Altitude  0.031708  99.984154
# 11  273.063  Altitude  0.013214  99.985344
# 12  274.094  Altitude  0.013214  99.985344
# 13  275.119  Altitude  0.000000  99.985474
# 14  276.147  Altitude  0.000000  99.985474

# %%
d = datapoint.gyroscope
fig, ax = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=False, figsize=(15, 10))
ax = ax.flatten()
fig.delaxes(ax[-1])
fig.suptitle(d.Sensor.loc[0])
for _ax, reading in zip(ax, ['X', 'Y', 'Z']):
    _ax.scatter(d.Time, d[reading])
    _ax.set_xlabel('Time')
    _ax.set_ylabel(reading)

# %%
b
# Out:
#          Time     Sensor  Rssi
# 0       0.000  Bluetooth -77.0
# 1       0.003  Bluetooth -77.0
# 2       0.067  Bluetooth -59.0
# 3       0.069  Bluetooth -59.0
# 4       0.195  Bluetooth -50.0
# ...       ...        ...   ...
# 1793  567.900  Bluetooth -74.0
# 1794  568.019  Bluetooth -74.0
# 1795  568.023  Bluetooth -74.0
# 1796  568.054  Bluetooth -74.0
# 1797  568.057  Bluetooth -74.0
#
# [1798 rows x 3 columns]

# %%
b = datapoint.bluetooth
plt.figure(figsize=(12, 8))
plt.scatter(b.Time, b['Rssi'], s=8)
plt.xlabel('Time')
plt.ylabel('BLE Rssi');

# %%
datapoint._plot(sensor='Bluetooth', t1=20., t2=100.)

# %%
b = datapoint.bluetooth
b = b[(b.Time >20.) & (b.Time < 100.)]
plt.scatter(b.Time, b.Rssi)

# %%
datapoint.bw(t1=20., t2=100., sensors=['Bluetooth'])
# Out:
#        Time     Sensor  Rssi
# 175  51.626  Bluetooth -51.0
# 176  51.629  Bluetooth -52.0
# 177  51.657  Bluetooth -54.0
# 178  51.660  Bluetooth -54.0
# 179  51.687  Bluetooth -72.0
# ..      ...        ...   ...
# 336  55.494  Bluetooth -54.0
# 337  55.523  Bluetooth -73.0
# 338  55.526  Bluetooth -73.0
# 339  55.552  Bluetooth -73.0
# 340  55.555  Bluetooth -73.0
#
# [166 rows x 3 columns]

# %%
b = datapoint.bluetooth
# Out:
#          Time     Sensor  Rssi
# 0       0.000  Bluetooth -77.0
# 1       0.003  Bluetooth -77.0
# 2       0.067  Bluetooth -59.0
# 3       0.069  Bluetooth -59.0
# 4       0.195  Bluetooth -50.0
# ...       ...        ...   ...
# 1793  567.900  Bluetooth -74.0
# 1794  568.019  Bluetooth -74.0
# 1795  568.023  Bluetooth -74.0
# 1796  568.054  Bluetooth -74.0
# 1797  568.057  Bluetooth -74.0
#
# [1798 rows x 3 columns]

# %% [markdown]
# ## Non-sensor Data

# %%
datapoint = DataPoint('data/tc4tl_training_data_v1/tc4tl/data/train/aaadbuvp_tc4tl20.csv')

# %%
datapoint.nsdata_dict
# Out:
# {'TXDevice': 'iPhoneX',
#  'TXPower': '12',
#  'RXDevice': 'iPhone8',
#  'TXCarry': 'pocket',
#  'RXCarry': 'hand',
#  'RXPose': 'standing',
#  'TXPose': 'standing'}

# %%
datapoint.TXPower
# Out:
# '12'
